# %%
from os import name
import pandas as pd
import streamlit as st
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
from PIL import Image
import datetime

# %%
import pandas as pd

# %%
df=pd.read_excel('Project/PMKVY DATA.xlsx')

# %%
df
# Out:
#               Candidate Name    Centre State  \
# 0           PAVADA SAIKUMARI  Andhra Pradesh
# 1       CHELUBOYINA SAILATHA  Andhra Pradesh
# 2        DAMARASINGI RAMESH   Andhra Pradesh
# 3         Boddana Vinodkumar  Andhra Pradesh
# 4      Dasari Satyannarayana  Andhra Pradesh
# ...                      ...             ...
# 40335          Botla Mounika       TELANGANA
# 40336          Gadam Deepthi       TELANGANA
# 40337      Lingubotu Deepika       TELANGANA
# 40338     Kallubhavi Lakshmi       TELANGANA
# 40339    GUDIYA KUMARI SINGH       TELANGANA
#
#                                             Centre Name Scheme  \
# 0                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 1                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 2                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 3                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 4                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# ...

# %%
df['Scheme'][0].split()[0]
# Out:
# 'PMKVY'

# %%
df.isna().sum()
# Out:
# Candidate Name          0
# Centre State            0
# Centre Name             0
# Scheme                  0
# Job Role                0
# Certified            7885
# Candidate Placed    25239
# Salary              40340
# TP1                 40340
# TP2                 40340
# TP3                 40340
# Year                    0
# dtype: int64

# %%
df['Certified'].shape
# Out:
# (40340,)

# %%
df['Certified']=df['Certified'].fillna('No')

# %%
df.isna().sum()
# Out:
# Candidate Name          0
# Centre State            0
# Centre Name             0
# Scheme                  0
# Job Role                0
# Certified               0
# Candidate Placed    25239
# Salary              40340
# TP1                 40340
# TP2                 40340
# TP3                 40340
# Year                    0
# dtype: int64

# %%
df['Candidate Placed']=df['Candidate Placed'].fillna('No')

# %%
df.isna().sum()
# Out:
# Candidate Name          0
# Centre State            0
# Centre Name             0
# Scheme                  0
# Job Role                0
# Certified               0
# Candidate Placed        0
# Salary              40340
# TP1                 40340
# TP2                 40340
# TP3                 40340
# Year                    0
# dtype: int64

# %%
df.head()
# Out:
#           Candidate Name    Centre State                          Centre Name  \
# 0       PAVADA SAIKUMARI  Andhra Pradesh  SynchroServe-AP-Vizianagaram-3 lamp
# 1   CHELUBOYINA SAILATHA  Andhra Pradesh  SynchroServe-AP-Vizianagaram-3 lamp
# 2    DAMARASINGI RAMESH   Andhra Pradesh  SynchroServe-AP-Vizianagaram-3 lamp
# 3     Boddana Vinodkumar  Andhra Pradesh  SynchroServe-AP-Vizianagaram-3 lamp
# 4  Dasari Satyannarayana  Andhra Pradesh  SynchroServe-AP-Vizianagaram-3 lamp
#
#   Scheme                   Job Role Certified Candidate Placed  Salary  TP1  \
# 0  PMKVY  Trainee Associate Level 3       Yes              Yes     NaN  NaN
# 1  PMKVY  Trainee Associate Level 3        No               No     NaN  NaN
# 2  PMKVY  Trainee Associate Level 3       Yes              Yes     NaN  NaN
# 3  PMKVY  Trainee Associate Level 3       Yes               No     NaN  NaN
# 4  PMKVY  Trainee Associate Level 3       Yes               No     NaN  NaN
#
#    TP2  TP3        Year
# ...

# %%
df['Year'].unique()
# Out:
# array(['2015-06-03', '2015-06-04', '2015-06-05', '2015-06-06',
#        '2015-06-08', '2015-06-13', '2015-06-17', '2015-06-18',
#        '2015-06-26', '2015-07-01', '2015-06-27', '2015-07-06',
#        '2015-07-09', '2015-07-16', '2015-06-29', '2015-07-13',
#        '2015-07-02', '2015-07-07', '2015-07-03', '2015-07-08',
#        '2015-07-10', '2015-07-11', '2015-07-14', '2015-07-15',
#        '2015-08-24', '2015-08-31', '2015-08-27', '2015-09-02',
#        '2015-09-01', '2015-09-03', '2015-09-04', '2015-09-30',
#        '2015-10-02', '2015-10-01', '2015-10-03', '2015-10-05',
#        '2015-10-27', '2015-10-28', '2015-10-29', '2015-10-30',
#        '2015-11-02', '2015-11-07', '2015-10-31', '2015-11-03',
#        '2015-11-09', '2015-11-04', '2015-11-06', '2015-11-05',
#        '2015-11-20', '2015-11-08', '2015-11-23', '2015-11-14',
#        '2015-11-18', '2015-11-16', '2015-12-01', '2015-11-28',
#        '2015-12-03', '2015-12-07', '2015-12-09', '2015-12-12',
# ...

# %%
df['Year'].shape
# Out:
# (40340,)

# %%
s='2015-07-02'
(s.split('-')[0])
# Out:
# '2015'

# %%
s='2015-07-02'
len(s.split('-')[0])
# Out:
# 4

# %%
s='2015-07-02'
s[4]
# Out:
# '-'

# %%
s='14/03/2020'
s[2]
# Out:
# '/'

# %%
s='14/03/2020'
(s.split('-'))
# Out:
# ['14/03/2020']

# %%
s='14/03/2020'
len(s)
# Out:
# 10

# %%
s='14/03/2020'
(s.split('/')[2])
# Out:
# '2020'

# %%
df_arr=[]

# %%
df_arr
# Out:
# []

# %%
for val in df['Year']:
    if type(val)==str:
        if val[4]=='-':
            df_arr.append(int(val.split('-')[0]))
        elif val[2]=='/':
            df_arr.append(int(val.split('/')[2])) 
            
    elif type(val)==datetime.datetime:
        df_arr.append(val.timetuple().tm_year)

# %%
np.array(df_arr).shape
# Out:
# (40340,)

# %%
df['Year']=df_arr

# %%
df
# Out:
#               Candidate Name    Centre State  \
# 0           PAVADA SAIKUMARI  Andhra Pradesh
# 1       CHELUBOYINA SAILATHA  Andhra Pradesh
# 2        DAMARASINGI RAMESH   Andhra Pradesh
# 3         Boddana Vinodkumar  Andhra Pradesh
# 4      Dasari Satyannarayana  Andhra Pradesh
# ...                      ...             ...
# 40335          Botla Mounika       TELANGANA
# 40336          Gadam Deepthi       TELANGANA
# 40337      Lingubotu Deepika       TELANGANA
# 40338     Kallubhavi Lakshmi       TELANGANA
# 40339    GUDIYA KUMARI SINGH       TELANGANA
#
#                                             Centre Name Scheme  \
# 0                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 1                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 2                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 3                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 4                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# ...

# %%
(df['Candidate Placed']=='Yes').sum()
# Out:
# 11518

# %%
(df['Candidate Placed']=='No').sum()
# Out:
# 28822

# %%
df['Candidate Placed'].isna().sum()
# Out:
# 0

# %%
df['Salary']=df['Candidate Placed']
df['TP1']=df['Candidate Placed']
df['TP2']=df['Candidate Placed']
df['TP3']=df['Candidate Placed']

# %%
df['Salary'].replace(to_replace='Yes',value=8000,inplace=True)

# %%
df['Salary'].unique()
# Out:
# array([11000, 'No'], dtype=object)

# %%
df
# Out:
#               Candidate Name    Centre State  \
# 0           PAVADA SAIKUMARI  Andhra Pradesh
# 1       CHELUBOYINA SAILATHA  Andhra Pradesh
# 2        DAMARASINGI RAMESH   Andhra Pradesh
# 3         Boddana Vinodkumar  Andhra Pradesh
# 4      Dasari Satyannarayana  Andhra Pradesh
# ...                      ...             ...
# 40335          Botla Mounika       TELANGANA
# 40336          Gadam Deepthi       TELANGANA
# 40337      Lingubotu Deepika       TELANGANA
# 40338     Kallubhavi Lakshmi       TELANGANA
# 40339    GUDIYA KUMARI SINGH       TELANGANA
#
#                                             Centre Name Scheme  \
# 0                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 1                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 2                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 3                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 4                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# ...

# %%
df1=df.drop(df.loc[df['Salary']=='No'].index)

# %%
df1
# Out:
#                  Candidate Name    Centre State  \
# 0              PAVADA SAIKUMARI  Andhra Pradesh
# 2           DAMARASINGI RAMESH   Andhra Pradesh
# 5            Suviki Pavan Kumar  Andhra Pradesh
# 6      VADDADHI VENKATA LAKSHMI  Andhra Pradesh
# 7                   Shaik Yusuf  Andhra Pradesh
# ...                         ...             ...
# 40306                M Priyanka       TELANGANA
# 40310         Nadigottu sujatha       TELANGANA
# 40313       Gatla Sudhir Swetha       TELANGANA
# 40315           Panjala Lavanya       TELANGANA
# 40334         Silamkoti sailaja       TELANGANA
#
#                                             Centre Name Scheme  \
# 0                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 2                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 5                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 6                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 7                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# ...

# %%
df
# Out:
#               Candidate Name    Centre State  \
# 0           PAVADA SAIKUMARI  Andhra Pradesh
# 1       CHELUBOYINA SAILATHA  Andhra Pradesh
# 2        DAMARASINGI RAMESH   Andhra Pradesh
# 3         Boddana Vinodkumar  Andhra Pradesh
# 4      Dasari Satyannarayana  Andhra Pradesh
# ...                      ...             ...
# 40335          Botla Mounika       TELANGANA
# 40336          Gadam Deepthi       TELANGANA
# 40337      Lingubotu Deepika       TELANGANA
# 40338     Kallubhavi Lakshmi       TELANGANA
# 40339    GUDIYA KUMARI SINGH       TELANGANA
#
#                                             Centre Name Scheme  \
# 0                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 1                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 2                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 3                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# 4                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# ...

# %%
df['TP1'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['TP1'].isna().sum()
# Out:
# 25239

# %%
df['Year'].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
df.shape
# Out:
# (40340, 9)

# %%
df['Certified'].shape
# Out:
# (40340,)

# %%
print((df['Certified']=="Yes").sum())## To know Number of People who r Certified!
print((df['Certified']=="No").sum())
# Out:
# 28053
# 9011

# %%
df['Certified'].unique()
# Out:
# array(['Yes', nan, 'No', 'FAIL', 'Not Appeared', 'PASS', 'Dropout'],
#       dtype=object)

# %%
print((df['Candidate Placed']=="Yes").sum())## To know Number of People who r Placed!
print((df['Candidate Placed']=="No").sum())
# Out:
# 11518
# 28822

# %%
df['Candidate Placed'].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df['Centre State'].unique() ## List of States where Our centres r located!
# Out:
# array(['Andhra Pradesh', 'Telangana', 'Uttar Pradesh', 'Jharkhand',
#        'Maharashtra', 'Bihar', 'Kerala', 'West Bengal', 'Karnataka',
#        'Rajasthan', 'Assam', 'Odisha', 'ANDHRA PRADESH', 'TELANGANA'],
#       dtype=object)

# %%
df.replace(to_replace='ANDHRA PRADESH',value='Andhra Pradesh',inplace=True)
df.replace(to_replace='TELANGANA',value='Telangana',inplace=True)

# %%
#centres done!
df['Centre State'].unique()
# Out:
# array(['Andhra Pradesh', 'Telangana', 'Uttar Pradesh', 'Jharkhand',
#        'Maharashtra', 'Bihar', 'Kerala', 'West Bengal', 'Karnataka',
#        'Rajasthan', 'Assam', 'Odisha'], dtype=object)

# %%
df['Centre Name'].unique() ## List of Center Names!
# Out:
# array(['SynchroServe-AP-Vizianagaram-3 lamp',
#        'SynchroServe-AP-Visakhapatnam-Vizag-Prism',
#        'SynchroServe-AP-Vizag-Pendurthi-Kites(LIC Office)',
#        'SynchroServe-AP-Anantapur-Sai Nagar',
#        'SynchroServe-AP-Guntur-Pattabhi Puram',
#        'SynchroServe-AP-Vizag-Sabavaram',
#        'SynchroServe-TS-Adilabad-Dwarakanagar',
#        'SynchroServe-AP-Visakhapatnam-Dabagardens',
#        'SynchroServe-AP-Prakasam-Ongole',
#        'SynchroServe-AP-Srikakulam-Genesis',
#        'SynchroServe-AP-Srikakulam-Prabhakar Nagar',
#        'SynchroServe-AP-Vizianagaram-Gajapathinagaram',
#        'SynchroServe-AP-Visakhapatnam-Anandapuram',
#        'SynchroServe-AP-Nellore-Gayathri Nagar',
#        'SynchroServe-AP-Chittoor-Tirupathi',
#        'SynchroServe-TS-Warangal-Lashkar Bazar',
#        'SynchroServe -TS-Khammam-Sattupally',
#        'SynchroServe-AP-Vizag-Anakapalli-Nehru Chowk',
#        'SynchroServe-AP-West Godavari-Jangareddygudem',
# ...

# %%
df['Centre Name'].unique().shape
# Out:
# (173,)

# %% [markdown]
# ## Remove unnecessary or Duplicate things in Eduation Level

# %%
df.head()
# Out:
#           Candidate Name  Gender Education Level    Centre State  \
# 0       PAVADA SAIKUMARI  Female        Graduate  Andhra Pradesh
# 1   CHELUBOYINA SAILATHA  Female      10th Class  Andhra Pradesh
# 2    DAMARASINGI RAMESH     Male     Polytechnic  Andhra Pradesh
# 3     Boddana Vinodkumar    Male        Graduate  Andhra Pradesh
# 4  Dasari Satyannarayana    Male        Graduate  Andhra Pradesh
#
#                            Centre Name Scheme                   Job Role  \
# 0  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
# 1  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
# 2  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
# 3  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
# 4  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
#
#   Certified Candidate Placed
# 0       Yes              Yes
# 1        No               No
# 2       Yes              Yes
# ...

# %%
df['Certified'].unique()
# Out:
# array(['Yes', 'No', 'FAIL', 'Not Appeared', 'PASS', 'Dropout'],
#       dtype=object)

# %%
df.replace(to_replace=['FAIL','Not Appeared','Dropout'],value='No',inplace=True)
df.replace(to_replace=['PASS'],value='Yes',inplace=True)

# %%
df['Certified'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Candidate Placed'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Scheme'].unique()# There's only 1 unique scheme till yet, cause it's the data of one part of the dump!
# Out:
# array(['PMKVY'], dtype=object)

# %%
df['Job Role'].unique() #To know the different types of Job Roles Available!
# Out:
# array(['Trainee Associate Level 3', 'Sales Associate Level 4',
#        'Assistant Electrician', 'Mason General',
#        'Domestic Data Entry Operator Level 4',
#        'Domestic IT Helpdesk Attendant Level 4',
#        'Jewellery Retail - Jewellery Retail Sales Associate (Basic)',
#        'Customer Care Executive (Call Centre) Level 4', 'Helper Mason',
#        'Inventory Clerk', 'Warehouse Packer', 'Meet & Greet Officer',
#        'Front Office Associate', 'Helper Construction Painter',
#        'Helper Electrician', 'Coffee Plantation Worker',
#        'Micro Irrigation Technician',
#        'Installation Technician (Computing & Peripherals)',
#        'Sewing Machine Operator',
#        'Field Technician-Networking and Storage',
#        'Field Technician Computing and Peripherals Level 4',
#        'Food & Beverage Service-Steward Level 4',
#        'CRM Domestic Non-Voice Level 4', 'Helper Shuttering Carpenter',
#        'Broadband Technician',
# ...

# %%
df['Job Role'].unique().shape
# Out:
# (75,)

# %%
    states = df['Centre State'].unique().tolist()
    #center_name = df['Centre Name'].unique().tolist()
    job_role = df['Job Role'].unique().tolist()
    scheme = df['Scheme'].unique().tolist()

    # Multiple States Selection
    states_selection = st.multiselect('STATE :',
                                      states, default=states)  # Set default=states(if by default all values r needed!)

    # Multiple Projects Selection
   # center_name_selection = c4.multiselect('CENTER :',
    # center_name, default=center_name)

   # c3, c4 = st.columns(2)
    # Multiple States Selection
    job_role_selection = st.multiselect('JOB ROLE :',
                                        job_role, default=job_role)  # Set default=gener(if by default all values r needed!)
    # Multiple Projects Selection
    scheme_selection = st.multiselect('SCHEME :',
                                      scheme, default=scheme)
    # Filter Data Based on User Selection
    mask =(df['Centre State'].isin(states_selection)) & (
            df['Job Role'].isin(job_role_selection)) & (df['Scheme'].isin(scheme_selection))
# Out:
# 2021-09-15 16:35:53.197
# ...
#   command:
#
#     streamlit run C:\Users\Acer\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
mask =  (df['Centre State'].isin(states_selection)) & (
            df['Job Role'].isin(job_role_selection)) & (df['Scheme'].isin(scheme_selection))

# %%
df.head()
# Out:
#           Candidate Name  Gender Education Level    Centre State  \
# 0       PAVADA SAIKUMARI  Female        Graduate  Andhra Pradesh
# 1   CHELUBOYINA SAILATHA  Female      10th Class  Andhra Pradesh
# 2    DAMARASINGI RAMESH     Male     Polytechnic  Andhra Pradesh
# 3     Boddana Vinodkumar    Male        Graduate  Andhra Pradesh
# 4  Dasari Satyannarayana    Male        Graduate  Andhra Pradesh
#
#                            Centre Name Scheme                   Job Role  \
# 0  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
# 1  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
# 2  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
# 3  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
# 4  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
#
#   Certified Candidate Placed
# 0       Yes              Yes
# 1        No               No
# 2       Yes              Yes
# ...

# %%
df[mask]
# Out:
#               Candidate Name  Gender Education Level    Centre State  \
# 0           PAVADA SAIKUMARI  Female        Graduate  Andhra Pradesh
# 1       CHELUBOYINA SAILATHA  Female      10th Class  Andhra Pradesh
# 2        DAMARASINGI RAMESH     Male     Polytechnic  Andhra Pradesh
# 3         Boddana Vinodkumar    Male        Graduate  Andhra Pradesh
# 4      Dasari Satyannarayana    Male        Graduate  Andhra Pradesh
# ...                      ...     ...             ...             ...
# 40335          Botla Mounika  Female      10th Class       Telangana
# 40336          Gadam Deepthi  Female      12th Class       Telangana
# 40337      Lingubotu Deepika  Female      10th Class       Telangana
# 40338     Kallubhavi Lakshmi  Female      12th Class       Telangana
# 40339    GUDIYA KUMARI SINGH  Female  Under Graduate       Telangana
#
#                                             Centre Name Scheme  \
# 0                   SynchroServe-AP-Vizianagaram-3 lamp  PMKVY
# ...

# %%
df[mask]['Candidate Name'].shape[0]
# Out:
# 40340

# %%
(df[mask]['Certified']=="Yes").sum()
# Out:
# 30441

# %%
(df[mask]['Candidate Placed']=="Yes").sum()
# Out:
# 11518

# %%
(df[mask]['Candidate Placed']=="No").sum()
# Out:
# 28822

# %%
 # Converting Categorical to Numerical Data to get the values count while plotting the data
df['Enrolled'] = 1  # A new column to know How many have enrolled!
df.loc[df['Certified'] == "Yes", 'Certified'] = 1
df.loc[df['Certified'] == "No", 'Certified'] = 0
df.loc[df['Candidate Placed'] == "Yes", 'Candidate Placed'] = 1
df.loc[df['Candidate Placed'] == "No", 'Candidate Placed'] = 0

# %%
df.head()
# Out:
#           Candidate Name  Gender Education Level    Centre State  \
# 0       PAVADA SAIKUMARI  Female        Graduate  Andhra Pradesh
# 1   CHELUBOYINA SAILATHA  Female      10th Class  Andhra Pradesh
# 2    DAMARASINGI RAMESH     Male     Polytechnic  Andhra Pradesh
# 3     Boddana Vinodkumar    Male        Graduate  Andhra Pradesh
# 4  Dasari Satyannarayana    Male        Graduate  Andhra Pradesh
#
#                            Centre Name Scheme                   Job Role  \
# 0  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
# 1  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
# 2  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
# 3  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
# 4  SynchroServe-AP-Vizianagaram-3 lamp  PMKVY  Trainee Associate Level 3
#
#   Certified Candidate Placed  Enrolled
# 0         1                1         1
# 1         0                0         1
# ...

# %%
df[mask].shape
# Out:
# (40340, 10)
