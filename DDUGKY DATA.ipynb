# %%
from os import name
import pandas as pd
import streamlit as st
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
from PIL import Image
import random
import datetime

# %%
df=pd.read_excel('Project/DDUGKY DATA.xlsx')

# %%
df
# Out:
#               Candidate Name    Centre State      Centre Name    Scheme  \
# 0                  MD FEROZA       Telangana  SSG-RR-MoulaAli  DDUGKY 1
# 1     ALAMPALLY VIJAYA KUMAR       Telangana  SSG-RR-MoulaAli  DDUGKY 1
# 2             BANDI SREEVANI       Telangana  SSG-RR-MoulaAli  DDUGKY 1
# 3            JOOLA SREELATHA       Telangana  SSG-RR-MoulaAli  DDUGKY 1
# 4                  R SANDHYA       Telangana  SSG-RR-MoulaAli  DDUGKY 1
# ...                      ...             ...              ...       ...
# 2659                  GANESH  ANDHRA PRADESH            VIZAG  DDUGKY 2
# 2660              SIVAKUMARI  ANDHRA PRADESH            VIZAG  DDUGKY 2
# 2661                KOTHAMMA  ANDHRA PRADESH            VIZAG  DDUGKY 2
# 2662               ACHIYAMMA  ANDHRA PRADESH            VIZAG  DDUGKY 2
# 2663               MATYARAJU  ANDHRA PRADESH            VIZAG  DDUGKY 2
#
#                           Job Role Certified Candidate Placed Salary  TP1  \
# ...

# %%
df['Scheme'][0].split()[0]
# Out:
# 'DDUGKY'

# %%
df.shape
# Out:
# (2664, 12)

# %%
df['Centre State'].unique()
# Out:
# array(['Telangana', 'ANDHRA PRADESH'], dtype=object)

# %%
df['Centre State'].replace(to_replace='ANDHRA PRADESH',value='Andhra Pradesh',inplace=True)

# %%
df['Centre State'].unique()
# Out:
# array(['Telangana', 'Andhra Pradesh'], dtype=object)

# %%
df['Scheme'].unique()
# Out:
# array(['DDUGKY 1', 'DDUGKY 2'], dtype=object)

# %%
# Cleaning data by replacing the duplicate values in it SCHEME
df.replace(to_replace=['DDUGKY 1', 'DDUGKY 2','DDUGKY-3'],value='DDUGKY',inplace=True)
df['Scheme']=df['Scheme'].fillna('DDUGKY')

# %%
df['Scheme'].unique()
# Out:
# array(['DDUGKY'], dtype=object)

# %%
df
# Out:
#               Candidate Name    Centre State      Centre Name  Scheme  \
# 0                  MD FEROZA       Telangana  SSG-RR-MoulaAli  DDUGKY
# 1     ALAMPALLY VIJAYA KUMAR       Telangana  SSG-RR-MoulaAli  DDUGKY
# 2             BANDI SREEVANI       Telangana  SSG-RR-MoulaAli  DDUGKY
# 3            JOOLA SREELATHA       Telangana  SSG-RR-MoulaAli  DDUGKY
# 4                  R SANDHYA       Telangana  SSG-RR-MoulaAli  DDUGKY
# ...                      ...             ...              ...     ...
# 2659                  GANESH  Andhra Pradesh            VIZAG  DDUGKY
# 2660              SIVAKUMARI  Andhra Pradesh            VIZAG  DDUGKY
# 2661                KOTHAMMA  Andhra Pradesh            VIZAG  DDUGKY
# 2662               ACHIYAMMA  Andhra Pradesh            VIZAG  DDUGKY
# 2663               MATYARAJU  Andhra Pradesh            VIZAG  DDUGKY
#
#                           Job Role Certified Candidate Placed Salary  TP1  \
# ...

# %%
df['Certified'].unique()
# Out:
# array(['Passed', 'Failed', 'Absent', nan, 'Not Declared', 'Pass', 'Fail',
#        'PASS', 'ABSENT', 'FAIL', 'Pending', 'Yes', 'No'], dtype=object)

# %%
# Duplicates & Null values CERTIFIED
df.replace(to_replace=['Passed','Pass','Not Declared','PASS','Pending'],value='Yes',inplace=True)
df.replace(to_replace=['Failed', 'No','Fail','ABSENT','FAIL','Absent'],value='No',inplace=True)
df['Certified']=df['Certified'].fillna('No')

# %%
df['Certified'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Candidate Placed'].unique()
# Out:
# array(['P', 'NP', 'Drop out', 'YES', 'NO', nan, 'ONGOING'], dtype=object)

# %%
# Duplicates & Null values PLACED
df.replace(to_replace=['P','YES'],value='Yes',inplace=True)
df.replace(to_replace=['NP', 'Drop out','NO','ONGOING'],value='No',inplace=True)
df['Candidate Placed']=df['Candidate Placed'].fillna('No')

# %%
df['Candidate Placed'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df
# Out:
#               Candidate Name    Centre State      Centre Name  Scheme  \
# 0                  MD FEROZA       Telangana  SSG-RR-MoulaAli  DDUGKY
# 1     ALAMPALLY VIJAYA KUMAR       Telangana  SSG-RR-MoulaAli  DDUGKY
# 2             BANDI SREEVANI       Telangana  SSG-RR-MoulaAli  DDUGKY
# 3            JOOLA SREELATHA       Telangana  SSG-RR-MoulaAli  DDUGKY
# 4                  R SANDHYA       Telangana  SSG-RR-MoulaAli  DDUGKY
# ...                      ...             ...              ...     ...
# 2659                  GANESH  Andhra Pradesh            VIZAG  DDUGKY
# 2660              SIVAKUMARI  Andhra Pradesh            VIZAG  DDUGKY
# 2661                KOTHAMMA  Andhra Pradesh            VIZAG  DDUGKY
# 2662               ACHIYAMMA  Andhra Pradesh            VIZAG  DDUGKY
# 2663               MATYARAJU  Andhra Pradesh            VIZAG  DDUGKY
#
#                           Job Role Certified Candidate Placed Salary  TP1  \
# ...

# %%
df['TP1'][df['Centre State']=='Andhra Pradesh']=df['Salary'].notna()
df['TP2'][df['Centre State']=='Andhra Pradesh']=df['Salary'].notna()
df['TP3'][df['Centre State']=='Andhra Pradesh']=df['Salary'].notna()

# %%
df
# Out:
#               Candidate Name    Centre State      Centre Name  Scheme  \
# 0                  MD FEROZA       Telangana  SSG-RR-MoulaAli  DDUGKY
# 1     ALAMPALLY VIJAYA KUMAR       Telangana  SSG-RR-MoulaAli  DDUGKY
# 2             BANDI SREEVANI       Telangana  SSG-RR-MoulaAli  DDUGKY
# 3            JOOLA SREELATHA       Telangana  SSG-RR-MoulaAli  DDUGKY
# 4                  R SANDHYA       Telangana  SSG-RR-MoulaAli  DDUGKY
# ...                      ...             ...              ...     ...
# 2659                  GANESH  Andhra Pradesh            VIZAG  DDUGKY
# 2660              SIVAKUMARI  Andhra Pradesh            VIZAG  DDUGKY
# 2661                KOTHAMMA  Andhra Pradesh            VIZAG  DDUGKY
# 2662               ACHIYAMMA  Andhra Pradesh            VIZAG  DDUGKY
# 2663               MATYARAJU  Andhra Pradesh            VIZAG  DDUGKY
#
#                           Job Role Certified Candidate Placed Salary    TP1  \
# ...

# %%
df[df['Centre State']=='Andhra Pradesh']
# Out:
#             Candidate Name    Centre State Centre Name  Scheme  \
# 1394              SIVA RAM  Andhra Pradesh       VIZAG  DDUGKY
# 1395                GANESH  Andhra Pradesh       VIZAG  DDUGKY
# 1396  UPENDRA PRUDHVI RAJU  Andhra Pradesh       VIZAG  DDUGKY
# 1397           VENKATA RAO  Andhra Pradesh       VIZAG  DDUGKY
# 1398     JANNARDHANA NAIDU  Andhra Pradesh       VIZAG  DDUGKY
# ...                    ...             ...         ...     ...
# 2659                GANESH  Andhra Pradesh       VIZAG  DDUGKY
# 2660            SIVAKUMARI  Andhra Pradesh       VIZAG  DDUGKY
# 2661              KOTHAMMA  Andhra Pradesh       VIZAG  DDUGKY
# 2662             ACHIYAMMA  Andhra Pradesh       VIZAG  DDUGKY
# 2663             MATYARAJU  Andhra Pradesh       VIZAG  DDUGKY
#
#              Job Role Certified Candidate Placed Salary    TP1    TP2    TP3  \
# 1394  INVENTORY CLERK       Yes              Yes   8000   True   True   True
# ...

# %%
df['TP1'].unique()
# Out:
# array(['Yes', 'No', nan, True, False], dtype=object)

# %%
df['TP1']=df['TP1'].fillna('No')
df['TP2']=df['TP2'].fillna('No')
df['TP3']=df['TP3'].fillna('No')

# %%
df['TP1'].unique()
# Out:
# array(['Yes', 'No', True, False], dtype=object)

# %%
df[df['Centre State']=='Andhra Pradesh']
# Out:
#             Candidate Name    Centre State Centre Name  Scheme  \
# 1394              SIVA RAM  Andhra Pradesh       VIZAG  DDUGKY
# 1395                GANESH  Andhra Pradesh       VIZAG  DDUGKY
# 1396  UPENDRA PRUDHVI RAJU  Andhra Pradesh       VIZAG  DDUGKY
# 1397           VENKATA RAO  Andhra Pradesh       VIZAG  DDUGKY
# 1398     JANNARDHANA NAIDU  Andhra Pradesh       VIZAG  DDUGKY
# ...                    ...             ...         ...     ...
# 2659                GANESH  Andhra Pradesh       VIZAG  DDUGKY
# 2660            SIVAKUMARI  Andhra Pradesh       VIZAG  DDUGKY
# 2661              KOTHAMMA  Andhra Pradesh       VIZAG  DDUGKY
# 2662             ACHIYAMMA  Andhra Pradesh       VIZAG  DDUGKY
# 2663             MATYARAJU  Andhra Pradesh       VIZAG  DDUGKY
#
#              Job Role Certified Candidate Placed Salary    TP1    TP2    TP3  \
# 1394  INVENTORY CLERK       Yes              Yes   8000   True   True   True
# ...

# %%
# Converting Categorical to Numerical Data to get the values count while plotting the data
df['Enrolled'] = 1  # A new column to know How many have enrolled!
df.loc[df['Certified'] == "Yes", 'Certified'] = 1
df.loc[df['Certified'] == "No", 'Certified'] = 0
df.loc[df['Candidate Placed'] == "Yes", 'Candidate Placed'] = 1
df.loc[df['Candidate Placed'] == "No", 'Candidate Placed'] = 0

# %%
df
# Out:
#               Candidate Name    Centre State      Centre Name  Scheme  \
# 0                  MD FEROZA       Telangana  SSG-RR-MoulaAli  DDUGKY
# 1     ALAMPALLY VIJAYA KUMAR       Telangana  SSG-RR-MoulaAli  DDUGKY
# 2             BANDI SREEVANI       Telangana  SSG-RR-MoulaAli  DDUGKY
# 3            JOOLA SREELATHA       Telangana  SSG-RR-MoulaAli  DDUGKY
# 4                  R SANDHYA       Telangana  SSG-RR-MoulaAli  DDUGKY
# ...                      ...             ...              ...     ...
# 2659                  GANESH  Andhra Pradesh            VIZAG  DDUGKY
# 2660              SIVAKUMARI  Andhra Pradesh            VIZAG  DDUGKY
# 2661                KOTHAMMA  Andhra Pradesh            VIZAG  DDUGKY
# 2662               ACHIYAMMA  Andhra Pradesh            VIZAG  DDUGKY
# 2663               MATYARAJU  Andhra Pradesh            VIZAG  DDUGKY
#
#                           Job Role Certified Candidate Placed Salary    TP1  \
# ...

# %%
df.loc[df['TP1'] == "Yes", 'TP1'] = 1
df.loc[df['TP1'] == "No", 'TP1'] = 0
df.loc[df['TP2'] == "Yes", 'TP2'] = 1
df.loc[df['TP2'] == "No", 'TP2'] = 0
df.loc[df['TP3'] == "Yes", 'TP3'] = 1
df.loc[df['TP3'] == "No", 'TP3'] = 0

# %%
df.loc[df['TP1'] == True, 'TP1'] = 1
df.loc[df['TP1'] == False, 'TP1'] = 0
df.loc[df['TP2'] == True, 'TP2'] = 1
df.loc[df['TP2'] == False, 'TP2'] = 0
df.loc[df['TP3'] == True, 'TP3'] = 1
df.loc[df['TP3'] == False, 'TP3'] = 0

# %%
df[df['Centre State']=='Andhra Pradesh']
# Out:
#             Candidate Name    Centre State Centre Name  Scheme  \
# 1394              SIVA RAM  Andhra Pradesh       VIZAG  DDUGKY
# 1395                GANESH  Andhra Pradesh       VIZAG  DDUGKY
# 1396  UPENDRA PRUDHVI RAJU  Andhra Pradesh       VIZAG  DDUGKY
# 1397           VENKATA RAO  Andhra Pradesh       VIZAG  DDUGKY
# 1398     JANNARDHANA NAIDU  Andhra Pradesh       VIZAG  DDUGKY
# ...                    ...             ...         ...     ...
# 2659                GANESH  Andhra Pradesh       VIZAG  DDUGKY
# 2660            SIVAKUMARI  Andhra Pradesh       VIZAG  DDUGKY
# 2661              KOTHAMMA  Andhra Pradesh       VIZAG  DDUGKY
# 2662             ACHIYAMMA  Andhra Pradesh       VIZAG  DDUGKY
# 2663             MATYARAJU  Andhra Pradesh       VIZAG  DDUGKY
#
#              Job Role Certified Candidate Placed Salary TP1 TP2 TP3  \
# 1394  INVENTORY CLERK         1                1   8000   1   1   1
# 1395  INVENTORY CLERK         1                0    NaN   0   0   0
# ...

# %%
df_arr=[]

# %%
for val in df['Year']:
    if type(val)==str:
        df_arr.append(int(val.split('-')[0]))
    elif type(val)==datetime.datetime:
        df_arr.append(val.timetuple().tm_year)

# %%
df_arr
# Out:
# [2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
# ...

# %%
np.array(df_arr).shape
# Out:
# (2664,)

# %%
df['Year']=df_arr

# %%
df
# Out:
#               Candidate Name    Centre State      Centre Name  Scheme  \
# 0                  MD FEROZA       Telangana  SSG-RR-MoulaAli  DDUGKY
# 1     ALAMPALLY VIJAYA KUMAR       Telangana  SSG-RR-MoulaAli  DDUGKY
# 2             BANDI SREEVANI       Telangana  SSG-RR-MoulaAli  DDUGKY
# 3            JOOLA SREELATHA       Telangana  SSG-RR-MoulaAli  DDUGKY
# 4                  R SANDHYA       Telangana  SSG-RR-MoulaAli  DDUGKY
# ...                      ...             ...              ...     ...
# 2659                  GANESH  Andhra Pradesh            VIZAG  DDUGKY
# 2660              SIVAKUMARI  Andhra Pradesh            VIZAG  DDUGKY
# 2661                KOTHAMMA  Andhra Pradesh            VIZAG  DDUGKY
# 2662               ACHIYAMMA  Andhra Pradesh            VIZAG  DDUGKY
# 2663               MATYARAJU  Andhra Pradesh            VIZAG  DDUGKY
#
#                           Job Role Certified Candidate Placed Salary TP1 TP2  \
# ...

# %%
df['Salary'].unique()
# Out:
# array([6500, nan, '6500 + food and accommodation',
#        '7000 + food and accommodation', '9500 + food and accommodation',
#        7500, 9000, 8000, '7770/-', '9060/-', '6000/- + Incentives',
#        '8900/-', '10979/-', 10500, '8270/-', '8000/-', '-', '10500/-',
#        '10000/-', '8500/- + Incentives', '8241/- + Incentives', '7500/-',
#        '9500/-', '6000/-', '7721/-', '7000/-', '12000/-', '13000/-',
#        10000, 'Rs 8000.00 and Food & Accomodation',
#        'Rs 11,000.00 and Food & Accomodation', 12000,
#        'Rs 8500.00 and Food & Accomodation', 8500, 9500, 12157, 9700,
#        9170.8, 10100, 11449, '8000.00 + Incentives', 9600,
#        '8000.00 + FOOD AND ACCOMMODATION',
#        'Rs. 8000.00 + FOOD AND ACCOMMODATION',
#        '7500.00 + ACCOMMODATION AND FOOD',
#        '7000.00 + INCENTIVES and ACCOMMODATION AND FOOD',
#        '7000.00 + ACCOMMODATION AND FOOD', 9400, 13000,
#        'Rs 11268.00 and ACCOMMODATION', '7500 + FOOD AND ACCOMMODATION',
# ...

# %%
## Converting String values to Numeric for analysis
df.replace(to_replace=['6500 + food and accommodation','7000/-'],value=7000,inplace=True)
df.replace(to_replace=['7000 + food and accommodation','7500/-','7000.00 + ACCOMMODATION AND FOOD','7000 + FOOD AND ACCOMMODATION','-'],value=7500,inplace=True)
df.replace(to_replace=['9500 + food and accommodation','10000/-','9229 + Food and Accomodation','₹ 9,831','₹ 9,223', '₹ 10,520'],value=10000,inplace=True)
df.replace(to_replace='7770/-',value=7700,inplace=True)
df.replace(to_replace='6000/- + Incentives',value=6500,inplace=True)
df.replace(to_replace='10979/-',value=10979,inplace=True)
df.replace(to_replace='8270/-',value=8270,inplace=True)
df.replace(to_replace=['8000/-','7500.00 + ACCOMMODATION AND FOOD','7000.00 + INCENTIVES and ACCOMMODATION AND FOOD','7500 + FOOD AND ACCOMMODATION','7900/-','7992/-','₹ 8,167'],value=8000,inplace=True)
df.replace(to_replace='10500/-',value=10500,inplace=True)
df.replace(to_replace=['8500/- + Incentives','8500.00 + ACCOMMODATION AND FOOD','9194/-','9000/-','8900/-','9060/-','9229/-','₹ 8,752', 9170.8],value=9000,inplace=True)
df.replace(to_replace='8241/- + Incentives',value=8800,inplace=True)
df.replace(to_replace=['9500/-','9362/-'],value=9500,inplace=True)
df.replace(to_replace='6000/-',value=6000,inplace=True)
df.replace(to_replace='7721/-',value=7721,inplace=True)
df.replace(to_replace=['12000/-','Rs 11268.00 and ACCOMMODATION','11490/-'],value=12000,inplace=True)
df.replace(to_replace='13000/-',value=13000,inplace=True)
df.replace(to_replace=['Rs 8000.00 and Food & Accomodation','8000.00 + Incentives','Rs. 8000.00 + FOOD AND ACCOMMODATION','8500/-','₹ 8,459','8000.00 + FOOD AND ACCOMMODATION'],value=8500,inplace=True)
df.replace(to_replace='Rs 11,000.00 and Food & Accomodation',value=11500,inplace=True)
df.replace(to_replace='Rs 8500.00 and Food & Accomodation',value=9000,inplace=True)
df.replace(to_replace=['11000/-','11067/-','₹ 10,400', '₹ 11,059', '₹ 10,589', '₹ 10,730'],value=11000,inplace=True)
df.replace(to_replace='15000/-',value=15000,inplace=True)
df.replace(to_replace='16000/-',value=16000,inplace=True)
df.replace(to_replace='19000/-',value=19000,inplace=True)
df.replace(to_replace=['₹ 4,791','₹ 5,157', '₹ 5,192'],value=5000,inplace=True)
df.replace(to_replace=['₹ 1,696','₹ 2,634'],value=2000,inplace=True)

# %%
(df['Salary']).unique()
# Out:
# array([ 6500.,    nan,  7000.,  7500., 10000.,  9000.,  8000.,  7700.,
#        10979., 10500.,  8270.,  8800.,  9500.,  6000.,  7721., 12000.,
#        13000.,  8500., 11500., 12157.,  9700., 10100., 11449.,  9600.,
#         9400., 12750., 10015., 10850., 11000., 15000., 16000., 19000.,
#         7800.,  8900.,  8200.,  9800.,  8600., 11200.,  9250.,  7938.,
#         7610.,  9481., 10085.,  9490.,  7400., 14000.,  9300.,  8100.,
#         8320.,  7200.,  8566.,  9200.,  8750.,  8960.,  8300., 18000.,
#         8533., 11300., 10200.])

# %%
df['Salary'].isna().sum()
# Out:
# 884

# %%
df['Salary'].shape
# Out:
# (2664,)

# %%
df['Salary'].isna().sum()
# Out:
# 884

# %%
df['TP1'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# GIves the value of the corresponding data of a specific column
(df.loc[df['TP1'] == 1,'Salary'])
# Out:
# 2021-09-22 10:52:36.876 INFO    numexpr.utils: NumExpr defaulting to 8 threads.
# 0        6500.0
# 1        6500.0
# 2        6500.0
# 3        6500.0
# 4        6500.0
#          ...
# 2602    10000.0
# 2604    10200.0
# 2605    10000.0
# 2611    10000.0
# 2612    10000.0
# Name: Salary, Length: 1873, dtype: float64

# %%
(df['TP1']==1).sum() ## 1st month salary
# Out:
# 1873

# %%
(df['TP1']==0).sum()
# Out:
# 791

# %%
df['TP2'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# GIves the value of the corresponding data of a specific column
(df.loc[df['TP2'] == 1,'Salary'])
# Out:
# 0        6500.0
# 2        6500.0
# 3        6500.0
# 4        6500.0
# 5        6500.0
#          ...
# 2602    10000.0
# 2604    10200.0
# 2605    10000.0
# 2611    10000.0
# 2612    10000.0
# Name: Salary, Length: 1608, dtype: float64

# %%
(df['TP2']==1).sum() ## 2nd month salary
# Out:
# 1608

# %%
(df['TP2']==0).sum()
# Out:
# 1056

# %%
df['TP3'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# GIves the value of the corresponding data of a specific column
(df.loc[df['TP3'] == 1,'Salary'])
# Out:
# 2        6500.0
# 3        6500.0
# 4        6500.0
# 5        6500.0
# 7        6500.0
#          ...
# 2602    10000.0
# 2604    10200.0
# 2605    10000.0
# 2611    10000.0
# 2612    10000.0
# Name: Salary, Length: 1458, dtype: float64

# %%
#Get the mean!
(df.loc[df['TP3'] == 1,'Salary']).mean()
# Out:
# 8874.151982378855

# %%
(df['TP3']==1).sum() ## 3rd month salary
# Out:
# 1458

# %%
(df['TP3']==0).sum()
# Out:
# 1206

# %%
df.isna().sum()
# Out:
# Candidate Name        0
# Centre State          0
# Centre Name           0
# Scheme                0
# Job Role              0
# Certified             0
# Candidate Placed      0
# Salary              884
# TP1                   0
# TP2                   0
# TP3                   0
# Year                  0
# Enrolled              0
# dtype: int64

# %%
## Fill all null values in P1,P2 & P3 with 0(as NO)
df.fillna(0,inplace=True)

# %%
df.head()
# Out:
#            Candidate Name Centre State      Centre Name  Scheme  \
# 0               MD FEROZA    Telangana  SSG-RR-MoulaAli  DDUGKY
# 1  ALAMPALLY VIJAYA KUMAR    Telangana  SSG-RR-MoulaAli  DDUGKY
# 2          BANDI SREEVANI    Telangana  SSG-RR-MoulaAli  DDUGKY
# 3         JOOLA SREELATHA    Telangana  SSG-RR-MoulaAli  DDUGKY
# 4               R SANDHYA    Telangana  SSG-RR-MoulaAli  DDUGKY
#
#                        Job Role  Certified  Candidate Placed  Salary  TP1  \
# 0  DOMESTIC DATA ENTRY OPERATOR          1                 1  6500.0    1
# 1  DOMESTIC DATA ENTRY OPERATOR          0                 1  6500.0    1
# 2  DOMESTIC DATA ENTRY OPERATOR          1                 1  6500.0    1
# 3  DOMESTIC DATA ENTRY OPERATOR          1                 1  6500.0    1
# 4  DOMESTIC DATA ENTRY OPERATOR          1                 1  6500.0    1
#
#    TP2  TP3  Year  Enrolled
# 0    1    0  2016         1
# 1    0    0  2016         1
# 2    1    1  2016         1
# ...

# %%
df.isna().sum()
# Out:
# Candidate Name      0
# Centre State        0
# Centre Name         0
# Scheme              0
# Job Role            0
# Certified           0
# Candidate Placed    0
# Salary              0
# TP1                 0
# TP2                 0
# TP3                 0
# Year                0
# Enrolled            0
# dtype: int64
